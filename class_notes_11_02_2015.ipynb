# %%
import numpy as np
# %matplotlib notebook
from matplotlib import pyplot

# %%
dist = np.random.normal(0, 1, 10000)
n, bins, patches = pyplot.hist(dist, bins = 50)
pyplot.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# dist.size is better than len(dist.shape)

# %%
pyplot.figure()
foo = 3 + 5*dist
pyplot.hist(foo, bins = 50)
# Out:
# <img src="data:image/png;base64,...">
# (array([   2.,    4.,    3.,    0.,    4.,   15.,   19.,   26.,   29.,
#           52.,   82.,   80.,  127.,  163.,  186.,  251.,  301.,  334.,
#          408.,  409.,  499.,  556.,  592.,  610.,  644.,  577.,  542.,
#          545.,  482.,  450.,  420.,  306.,  263.,  237.,  213.,  145.,
#          118.,   93.,   73.,   39.,   36.,   22.,    9.,   15.,    8.,
#            7.,    3.,    0.,    0.,    1.]),
#  array([-15.45411208, -14.70141565, -13.94871923, -13.1960228 ,
#         -12.44332638, -11.69062995, -10.93793353, -10.18523711,
#          -9.43254068,  -8.67984426,  -7.92714783,  -7.17445141,
#          -6.42175498,  -5.66905856,  -4.91636213,  -4.16366571,
#          -3.41096928,  -2.65827286,  -1.90557644,  -1.15288001,
#          -0.40018359,   0.35251284,   1.10520926,   1.85790569,
#           2.61060211,   3.36329854,   4.11599496,   4.86869139,
#           5.62138781,   6.37408423,   7.12678066,   7.87947708,
# ...

# %% [markdown]
# ## Masking

# %%
foo = 3 + 5*dist
foo.sort()
print foo
# Out:
# [-15.45411208 -15.02948993 -14.58058633 ...,  19.66265383  19.69927239
#   22.18070915]

# %%
mask = (foo >-2) & (foo<8)
foo[mask]
# Out:
# array([-1.99961978, -1.99871121, -1.99856948, ...,  7.99131144,
#         7.99205156,  7.99338967])

# %%
mask2 = np.logical_and(foo > -2, foo < 8)

# %%
foo[mask2]
# Out:
# array([-1.99961978, -1.99871121, -1.99856948, ...,  7.99131144,
#         7.99205156,  7.99338967])

# %% [markdown]
# ## Limits

# %%
#Get limits
print foo[1600], foo[-1600]
# Out:
# -2.0735681652 7.86996563602

# %%
import astropy
astropy.__version__
# Out:
# u'1.0.3'

# %% [markdown]
# ## Mutable vs Inmutable objects

# %%
foo = [1, 2, 3]
foo2 = foo
foo = [3, 3, 3]
print foo2
# Out:
# [1, 2, 3]

# %%
foo = [1, 2, 3]
foo2 = foo
foo[1] = 5
print foo2
# Out:
# [1, 5, 3]

# %%
foo = 3
foo2 = foo
foo = 5
print foo2
# Out:
# 3

# %%
foo = np.ones((3, 3))

# %%
foo.flatten()
# Out:
# array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.,  1.,  1.])
